# %% [raw]
# ---
# title: "About"
# ---
#
# # Python
#
# ## Markdown
#
# ### Jupyternotebook
#
# ## Introduction
# Lorem ipsum dolor sit amet, consectetur adipiscing elit. Proin ac massa et dui viverra cursus.

# %%
import matplotlib.pyplot as plt
import numpy as np
# X axis parameter:
xaxis = np.array([2, 8])
# Y axis parameter:
yaxis = np.array([4, 9])
plt.plot(xaxis, yaxis)
plt.show()

# %% [markdown]
# About this site
